# %% [markdown]
# <a href="https://colab.research.google.com/github/borundev/DNN_Lectures/blob/master/Gambler's_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# number of states
n=101

# %%
# Analysis with discount factor 1

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.4
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.49
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (2.96637714392034e-16, 26)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.5
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (1.249000902703301e-16, 16)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.51
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (9.992007221626409e-16, 19453)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (9.992007221626409e-16, 2874)

# %%
# Analysis with discount factor 1-1e-5

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.49
pt=(1-ph)

# discount factor
gamma=1-1e-5

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1-1e-5

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()
